# %%
from datetime import datetime
from IPython.display import display, Markdown
import pandas as pd
import numpy as np
import os
pd.set_option("display.max_rows", 200)
pd.options.display.float_format = "{:,.1f}".format
float_formatter = "{:,.0f}".format
from utilities import *

# %%
print(os.path.join(
        OUTPUT_DIR, 'joined', 'summary', f'measure_ast007.csv'))

df = pd.read_csv(os.path.join(OUTPUT_DIR, 'joined', 'summary', f'measure_ast007.csv'))
# Out:
# c:\Users\higginsr\Documents\GitHub\asthma_indicators_qof\output\joined\summary\measure_ast007.csv

# %%
# Update labels for IMD
df.loc[(df["category"]=="imd") & (df["group"]=='1'),"group"]='1 - Most deprived'
df.loc[(df["category"]=="imd") & (df["group"]=='5'),"group"]='5 - Least deprived'
df.loc[(df["category"]=="imd") & (df["group"]=='missing'),"group"]='(Missing)'

# Update care_home flags
df.loc[(df["category"]=="care_home") & (df["group"]=='1'),"group"]='Yes'
df.loc[(df["category"]=="care_home") & (df["group"]=='0'),"group"]='No'

# Update learning_disability flags
df.loc[(df["category"]=="learning_disability") & (df["group"]=='1'),"group"]='Yes'
df.loc[(df["category"]=="learning_disability") & (df["group"]=='0'),"group"]='No'

# Update sex flags
df.loc[(df["category"]=="sex") & (df["group"]=='F'),"group"]='Female'
df.loc[(df["category"]=="sex") & (df["group"]=='M'),"group"]='Male'

# Update ethnicity flags
df.loc[(df["category"]=="sex") & (df["group"]==''),"group"]='Unknown'

# %%
df2 = pd.pivot_table(df[df.date == '2022-03-01'],index=['category','group'],values=['numerator','denominator', 'value'])
df2 = df2[['numerator','denominator','value']]

# %%
# Update order of categories in the table
df3 = df2.loc[['population','sex','age_band','ethnicity','imd','region','care_home','learning_disability']]
# Udpdate names of rows and columns
df4 = df3.rename(columns={'numerator':'Numerator','denominator':'Denominator','value':'Percentage'}
        , index={'population':'Population','sex':'Sex','age_band':'Age band','ethnicity':'Ethnicity'
            ,'imd':'IMD','region':'Region','care_home':'Care home status','learning_disability':'Record of learning disability'
            ,'F':'Female','M':'Male'})
# Remove multi index labels
df4.index.names = [None,None]
# Out:
#                                                         Numerator  \
# Population                    Population                    500.0
# Sex                           Female                        240.0
#                               Male                          260.0
# Age band                      0-19                           70.0
#                               20-29                          70.0
#                               30-39                          70.0
#                               40-49                          60.0
#                               50-59                          60.0
#                               60-69                          50.0
#                               70-79                          70.0
# Ethnicity                     Black                           NaN
#                               South Asian                     NaN
#                               White                           NaN
# IMD                           (Missing)                      20.0
#                               1 - Most deprived             100.0
#                               2                              90.0
#                               3                             110.0
#                               4                             100.0
#                               5 - Least deprived             80.0
# Region                        East                           50.0
#                               East Midlands                  50.0
#                               London                        100.0
#                               North East                     60.0
#                               North West                     40.0
#                               South East                     40.0
#                               South West                     50.0
#                               West Midlands                  50.0
#                               Yorkshire and The Humber       50.0
# Care home status              No                            400.0
#                               Yes                           100.0
# Record of learning disability No                              NaN
#                               Yes                             NaN
#
#                                                         Denominator  \
# Population                    Population                    1,000.0
# Sex                           Female                          470.0
#                               Male                            530.0
# Age band                      0-19                            140.0
#                               20-29                           130.0
#                               30-39                           140.0
#                               40-49                           120.0
#                               50-59                           120.0
#                               60-69                           110.0
#                               70-79                           130.0
# Ethnicity                     Black                            10.0
#                               South Asian                      10.0
#                               White                            10.0
# IMD                           (Missing)                        40.0
#                               1 - Most deprived               200.0
#                               2                               190.0
#                               3                               220.0
#                               4                               200.0
#                               5 - Least deprived              150.0
# Region                        East                            110.0
#                               East Midlands                   100.0
#                               London                          200.0
#                               North East                      100.0
#                               North West                      100.0
#                               South East                       80.0
#                               South West                      100.0
#                               West Midlands                   100.0
#                               Yorkshire and The Humber        100.0
# Care home status              No                              800.0
#                               Yes                             200.0
# Record of learning disability No                              990.0
#                               Yes                              10.0
#
#                                                         Percentage
# Population                    Population                       0.5
# Sex                           Female                           0.5
#                               Male                             0.5
# Age band                      0-19                             0.5
#                               20-29                            0.5
#                               30-39                            0.5
#                               40-49                            0.5
#                               50-59                            0.5
#                               60-69                            0.5
#                               70-79                            0.5
# Ethnicity                     Black                            NaN
#                               South Asian                      NaN
#                               White                            NaN
# IMD                           (Missing)                        0.5
#                               1 - Most deprived                0.5
#                               2                                0.5
#                               3                                0.5
#                               4                                0.5
#                               5 - Least deprived               0.5
# Region                        East                             0.5
#                               East Midlands                    0.5
#                               London                           0.5
#                               North East                       0.6
#                               North West                       0.4
#                               South East                       0.5
#                               South West                       0.5
#                               West Midlands                    0.5
#                               Yorkshire and The Humber         0.5
# Care home status              No                               0.5
#                               Yes                              0.5
# Record of learning disability No                               NaN
#                               Yes                              NaN

# %%
# Change all NULL values from NaN to '-'
df5 = df4.style.format({'Denominator': "{:,.0f}".format, 'Numerator': "{:,.0f}".format, 'Percentage':"{0:.2%}".format}, na_rep="-")
df5
# Out:
# <style type="text/css">
# </style>
# <table id="T_1378c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Numerator</th>
#       <th class="col_heading level0 col1" >Denominator</th>
#       <th class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1378c_level0_row0" class="row_heading level0 row0" >Population</th>
#       <th id="T_1378c_level1_row0" class="row_heading level1 row0" >Population</th>
#       <td id="T_1378c_row0_col0" class="data row0 col0" >500</td>
#       <td id="T_1378c_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_1378c_row0_col2" class="data row0 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level0_row1" class="row_heading level0 row1" rowspan="2">Sex</th>
#       <th id="T_1378c_level1_row1" class="row_heading level1 row1" >Female</th>
#       <td id="T_1378c_row1_col0" class="data row1 col0" >240</td>
#       <td id="T_1378c_row1_col1" class="data row1 col1" >470</td>
#       <td id="T_1378c_row1_col2" class="data row1 col2" >51.06%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row2" class="row_heading level1 row2" >Male</th>
#       <td id="T_1378c_row2_col0" class="data row2 col0" >260</td>
#       <td id="T_1378c_row2_col1" class="data row2 col1" >530</td>
#       <td id="T_1378c_row2_col2" class="data row2 col2" >49.06%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level0_row3" class="row_heading level0 row3" rowspan="7">Age band</th>
#       <th id="T_1378c_level1_row3" class="row_heading level1 row3" >0-19</th>
#       <td id="T_1378c_row3_col0" class="data row3 col0" >70</td>
#       <td id="T_1378c_row3_col1" class="data row3 col1" >140</td>
#       <td id="T_1378c_row3_col2" class="data row3 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row4" class="row_heading level1 row4" >20-29</th>
#       <td id="T_1378c_row4_col0" class="data row4 col0" >70</td>
#       <td id="T_1378c_row4_col1" class="data row4 col1" >130</td>
#       <td id="T_1378c_row4_col2" class="data row4 col2" >53.85%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row5" class="row_heading level1 row5" >30-39</th>
#       <td id="T_1378c_row5_col0" class="data row5 col0" >70</td>
#       <td id="T_1378c_row5_col1" class="data row5 col1" >140</td>
#       <td id="T_1378c_row5_col2" class="data row5 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row6" class="row_heading level1 row6" >40-49</th>
#       <td id="T_1378c_row6_col0" class="data row6 col0" >60</td>
#       <td id="T_1378c_row6_col1" class="data row6 col1" >120</td>
#       <td id="T_1378c_row6_col2" class="data row6 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row7" class="row_heading level1 row7" >50-59</th>
#       <td id="T_1378c_row7_col0" class="data row7 col0" >60</td>
#       <td id="T_1378c_row7_col1" class="data row7 col1" >120</td>
#       <td id="T_1378c_row7_col2" class="data row7 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row8" class="row_heading level1 row8" >60-69</th>
#       <td id="T_1378c_row8_col0" class="data row8 col0" >50</td>
#       <td id="T_1378c_row8_col1" class="data row8 col1" >110</td>
#       <td id="T_1378c_row8_col2" class="data row8 col2" >45.45%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row9" class="row_heading level1 row9" >70-79</th>
#       <td id="T_1378c_row9_col0" class="data row9 col0" >70</td>
#       <td id="T_1378c_row9_col1" class="data row9 col1" >130</td>
#       <td id="T_1378c_row9_col2" class="data row9 col2" >53.85%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level0_row10" class="row_heading level0 row10" rowspan="3">Ethnicity</th>
#       <th id="T_1378c_level1_row10" class="row_heading level1 row10" >Black</th>
#       <td id="T_1378c_row10_col0" class="data row10 col0" >-</td>
#       <td id="T_1378c_row10_col1" class="data row10 col1" >10</td>
#       <td id="T_1378c_row10_col2" class="data row10 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row11" class="row_heading level1 row11" >South Asian</th>
#       <td id="T_1378c_row11_col0" class="data row11 col0" >-</td>
#       <td id="T_1378c_row11_col1" class="data row11 col1" >10</td>
#       <td id="T_1378c_row11_col2" class="data row11 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row12" class="row_heading level1 row12" >White</th>
#       <td id="T_1378c_row12_col0" class="data row12 col0" >-</td>
#       <td id="T_1378c_row12_col1" class="data row12 col1" >10</td>
#       <td id="T_1378c_row12_col2" class="data row12 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level0_row13" class="row_heading level0 row13" rowspan="6">IMD</th>
#       <th id="T_1378c_level1_row13" class="row_heading level1 row13" >(Missing)</th>
#       <td id="T_1378c_row13_col0" class="data row13 col0" >20</td>
#       <td id="T_1378c_row13_col1" class="data row13 col1" >40</td>
#       <td id="T_1378c_row13_col2" class="data row13 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row14" class="row_heading level1 row14" >1 - Most deprived</th>
#       <td id="T_1378c_row14_col0" class="data row14 col0" >100</td>
#       <td id="T_1378c_row14_col1" class="data row14 col1" >200</td>
#       <td id="T_1378c_row14_col2" class="data row14 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row15" class="row_heading level1 row15" >2</th>
#       <td id="T_1378c_row15_col0" class="data row15 col0" >90</td>
#       <td id="T_1378c_row15_col1" class="data row15 col1" >190</td>
#       <td id="T_1378c_row15_col2" class="data row15 col2" >47.37%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row16" class="row_heading level1 row16" >3</th>
#       <td id="T_1378c_row16_col0" class="data row16 col0" >110</td>
#       <td id="T_1378c_row16_col1" class="data row16 col1" >220</td>
#       <td id="T_1378c_row16_col2" class="data row16 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row17" class="row_heading level1 row17" >4</th>
#       <td id="T_1378c_row17_col0" class="data row17 col0" >100</td>
#       <td id="T_1378c_row17_col1" class="data row17 col1" >200</td>
#       <td id="T_1378c_row17_col2" class="data row17 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row18" class="row_heading level1 row18" >5 - Least deprived</th>
#       <td id="T_1378c_row18_col0" class="data row18 col0" >80</td>
#       <td id="T_1378c_row18_col1" class="data row18 col1" >150</td>
#       <td id="T_1378c_row18_col2" class="data row18 col2" >53.33%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level0_row19" class="row_heading level0 row19" rowspan="9">Region</th>
#       <th id="T_1378c_level1_row19" class="row_heading level1 row19" >East</th>
#       <td id="T_1378c_row19_col0" class="data row19 col0" >50</td>
#       <td id="T_1378c_row19_col1" class="data row19 col1" >110</td>
#       <td id="T_1378c_row19_col2" class="data row19 col2" >45.45%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row20" class="row_heading level1 row20" >East Midlands</th>
#       <td id="T_1378c_row20_col0" class="data row20 col0" >50</td>
#       <td id="T_1378c_row20_col1" class="data row20 col1" >100</td>
#       <td id="T_1378c_row20_col2" class="data row20 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row21" class="row_heading level1 row21" >London</th>
#       <td id="T_1378c_row21_col0" class="data row21 col0" >100</td>
#       <td id="T_1378c_row21_col1" class="data row21 col1" >200</td>
#       <td id="T_1378c_row21_col2" class="data row21 col2" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row22" class="row_heading level1 row22" >North East</th>
#       <td id="T_1378c_row22_col0" class="data row22 col0" >60</td>
#       <td id="T_1378c_row22_col1" class="data row22 col1" >100</td>
#       <td id="T_1378c_row22_col2" class="data row22 col2" >60.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1378c_level1_row23" class="row_heading level1 row23" >North West</th>
#       <td id=
